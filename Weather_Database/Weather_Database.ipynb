# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy


cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 761

# %%
# Import the requests library.
import requests

# Import the API key. The config file containing the key runs easier in the same folder as the working file.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1


for i, city in enumerate(cities):
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    print(f"Processing Record {record_count} | {city}")
    
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #Index 0 after weather because description is in a single listed dictionary in the JSON file.
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | belozerskoye
# Processing Record 2 | mahebourg
# Processing Record 3 | rawson
# Processing Record 4 | hermanus
# Processing Record 5 | bluff
# Processing Record 6 | albany
# Processing Record 7 | kavieng
# Processing Record 8 | port alfred
# Processing Record 9 | rikitea
# Processing Record 10 | torbay
# Processing Record 11 | punta arenas
# Processing Record 12 | san patricio
# Processing Record 13 | eckernforde
# Processing Record 14 | vikulovo
# Processing Record 15 | kapaa
# Processing Record 16 | khani
# Processing Record 17 | cafarnaum
# Processing Record 18 | yerbogachen
# Processing Record 19 | yarmouth
# Processing Record 20 | bambous virieux
# Processing Record 21 | khatanga
# Processing Record 22 | eydhafushi
# Processing Record 23 | lebu
# Processing Record 24 | belushya guba
# City not found. Skipping...
# Processing Record 25 | manokwari
# Processing Record 26 | ushuaia
# Processing Record 27 | unye
# City not found. Skipping...
# Processing Record 28 | champasak
# Processing Record 29 | amderma
# City not found. Skipping...
# Processing Record 30 | umzimvubu
# City not found. Skipping...
# Processing Record 31 | itaueira
# Processing Record 32 | saint andrews
# Processing Record 33 | cape town
# Processing Record 34 | lompoc
# Processing Record 35 | luzhou
# Processing Record 36 | lianzhou
# Processing Record 37 | busselton
# Processing Record 38 | bara
# Processing Record 39 | rauma
# Processing Record 40 | thinadhoo
# Processing Record 41 | east london
# Processing Record 42 | sitka
# Processing Record 43 | butaritari
# Processing Record 44 | richards bay
# Processing Record 45 | grindavik
# Processing Record 46 | buala
# Processing Record 47 | sola
# Processing Record 48 | kamenskoye
# City not found. Skipping...
# Processing Record 49 | atakpame
# Processing Record 50 | provideniya
# Processing Record 51 | kodiak
# Processing Record 52 | evensk
# Processing Record 53 | kazalinsk
# City not found. Skipping...
# Processing Record 54 | vanimo
# Processing Record 55 | dikson
# Processing Record 56 | columbia
# Processing Record 57 | taolanaro
# City not found. Skipping...
# Processing Record 58 | longyearbyen
# Processing Record 59 | onega
# Processing Record 60 | rio gallegos
# Processing Record 61 | magadan
# Processing Record 62 | jamestown
# Processing Record 63 | antofagasta
# Processing Record 64 | sayyan
# Processing Record 65 | namibe
# Processing Record 66 | yichun
# Processing Record 67 | codajas
# Processing Record 68 | hithadhoo
# Processing Record 69 | tuburan
# Processing Record 70 | upernavik
# Processing Record 71 | geraldton
# Processing Record 72 | cherskiy
# Processing Record 73 | new norfolk
# Processing Record 74 | hualmay
# Processing Record 75 | aswan
# Processing Record 76 | mataura
# Processing Record 77 | mar del plata
# Processing Record 78 | pevek
# Processing Record 79 | airai
# Processing Record 80 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 81 | portland
# Processing Record 82 | kaitangata
# Processing Record 83 | domna
# Processing Record 84 | cockburn town
# Processing Record 85 | fairbanks
# Processing Record 86 | vaini
# Processing Record 87 | calderitas
# Processing Record 88 | mount gambier
# Processing Record 89 | abeche
# Processing Record 90 | mareeba
# Processing Record 91 | nakano
# Processing Record 92 | nelson bay
# Processing Record 93 | hobart
# Processing Record 94 | thompson
# Processing Record 95 | anrochte
# Processing Record 96 | kavaratti
# Processing Record 97 | esperance
# Processing Record 98 | gravdal
# Processing Record 99 | faridan
# City not found. Skipping...
# Processing Record 100 | elko
# Processing Record 101 | attawapiskat
# City not found. Skipping...
# Processing Record 102 | cabo san lucas
# Processing Record 103 | camacha
# Processing Record 104 | avarua
# Processing Record 105 | riyadh
# Processing Record 106 | bichura
# Processing Record 107 | kununurra
# Processing Record 108 | katangli
# Processing Record 109 | cuajinicuilapa
# Processing Record 110 | springbok
# Processing Record 111 | bredasdorp
# Processing Record 112 | dunedin
# Processing Record 113 | souillac
# Processing Record 114 | kruisfontein
# Processing Record 115 | verkhoyansk
# Processing Record 116 | saint-philippe
# Processing Record 117 | nizhneyansk
# City not found. Skipping...
# Processing Record 118 | krasnoyarskiy
# Processing Record 119 | lagoa
# Processing Record 120 | los llanos de aridane
# Processing Record 121 | srednekolymsk
# Processing Record 122 | tolbazy
# Processing Record 123 | williston
# Processing Record 124 | pangody
# Processing Record 125 | alamosa
# Processing Record 126 | yellowknife
# Processing Record 127 | kilindoni
# Processing Record 128 | sulangan
# Processing Record 129 | saskylakh
# Processing Record 130 | corpus christi
# Processing Record 131 | berlevag
# Processing Record 132 | kisiwani
# Processing Record 133 | chizhou
# Processing Record 134 | lampang
# Processing Record 135 | aklavik
# Processing Record 136 | bethel
# Processing Record 137 | zwedru
# Processing Record 138 | flin flon
# Processing Record 139 | hovd
# Processing Record 140 | narsaq
# Processing Record 141 | yerkoy
# Processing Record 142 | mapiripan
# Processing Record 143 | touros
# Processing Record 144 | ribeira grande
# Processing Record 145 | qaanaaq
# Processing Record 146 | gujan-mestras
# Processing Record 147 | ahumada
# City not found. Skipping...
# Processing Record 148 | clyde river
# Processing Record 149 | iqaluit
# Processing Record 150 | faanui
# Processing Record 151 | nizhniy ingash
# Processing Record 152 | karaul
# City not found. Skipping...
# Processing Record 153 | louisbourg
# City not found. Skipping...
# Processing Record 154 | flinders
# Processing Record 155 | castro
# Processing Record 156 | okha
# Processing Record 157 | sao jose da coroa grande
# Processing Record 158 | stoyba
# City not found. Skipping...
# Processing Record 159 | hilo
# Processing Record 160 | manono
# Processing Record 161 | nikolskoye
# Processing Record 162 | turukhansk
# Processing Record 163 | senneterre
# Processing Record 164 | alindao
# Processing Record 165 | bengkulu
# Processing Record 166 | anastacio
# Processing Record 167 | kimbe
# Processing Record 168 | tasiilaq
# Processing Record 169 | georgetown
# Processing Record 170 | bolungarvik
# City not found. Skipping...
# Processing Record 171 | charters towers
# Processing Record 172 | grand river south east
# City not found. Skipping...
# Processing Record 173 | saldanha
# Processing Record 174 | eenhana
# Processing Record 175 | surt
# Processing Record 176 | pisco
# Processing Record 177 | puerto ayora
# Processing Record 178 | gat
# Processing Record 179 | morgantown
# Processing Record 180 | henties bay
# Processing Record 181 | upata
# Processing Record 182 | gamba
# Processing Record 183 | necochea
# Processing Record 184 | vila velha
# Processing Record 185 | vao
# Processing Record 186 | atuona
# Processing Record 187 | barrow
# Processing Record 188 | cidreira
# Processing Record 189 | soto la marina
# Processing Record 190 | kadoma
# Processing Record 191 | emba
# Processing Record 192 | santa cruz del sur
# Processing Record 193 | half moon bay
# Processing Record 194 | norman wells
# Processing Record 195 | novobiryusinskiy
# Processing Record 196 | port blair
# Processing Record 197 | ostrovnoy
# Processing Record 198 | kirakira
# Processing Record 199 | staraya poltavka
# Processing Record 200 | kerchevskiy
# Processing Record 201 | lodwar
# Processing Record 202 | buraydah
# Processing Record 203 | pangnirtung
# Processing Record 204 | villa carlos paz
# Processing Record 205 | sorvag
# City not found. Skipping...
# Processing Record 206 | lima
# Processing Record 207 | imphal
# Processing Record 208 | natitingou
# Processing Record 209 | port elizabeth
# Processing Record 210 | kargasok
# Processing Record 211 | harper
# Processing Record 212 | severo-kurilsk
# Processing Record 213 | najran
# Processing Record 214 | carnarvon
# Processing Record 215 | victor harbor
# Processing Record 216 | santander
# Processing Record 217 | kamaishi
# Processing Record 218 | saint george
# Processing Record 219 | vila franca do campo
# Processing Record 220 | fukue
# Processing Record 221 | chokurdakh
# Processing Record 222 | skagastrond
# City not found. Skipping...
# Processing Record 223 | brokopondo
# Processing Record 224 | mehamn
# Processing Record 225 | korla
# Processing Record 226 | caravelas
# Processing Record 227 | nouakchott
# Processing Record 228 | guerrero negro
# Processing Record 229 | chapeco
# Processing Record 230 | palmer
# Processing Record 231 | samarai
# Processing Record 232 | guangyuan
# Processing Record 233 | okrika
# Processing Record 234 | banda aceh
# Processing Record 235 | san cristobal
# Processing Record 236 | dudinka
# Processing Record 237 | garissa
# Processing Record 238 | chara
# Processing Record 239 | nogent-le-rotrou
# Processing Record 240 | olinda
# Processing Record 241 | pemba
# Processing Record 242 | beringovskiy
# Processing Record 243 | ixtapa
# Processing Record 244 | nioaque
# Processing Record 245 | hoquiam
# Processing Record 246 | san rafael del sur
# Processing Record 247 | lorengau
# Processing Record 248 | itarema
# Processing Record 249 | mogadishu
# Processing Record 250 | hohhot
# Processing Record 251 | khandyga
# Processing Record 252 | vilhena
# Processing Record 253 | byron bay
# Processing Record 254 | talnakh
# Processing Record 255 | aguada
# Processing Record 256 | lamar
# Processing Record 257 | kizema
# Processing Record 258 | tuatapere
# Processing Record 259 | tirukkoyilur
# Processing Record 260 | san miguel de cauri
# Processing Record 261 | kristiansund
# Processing Record 262 | arman
# Processing Record 263 | kampene
# Processing Record 264 | kyzyl-suu
# Processing Record 265 | alta floresta
# Processing Record 266 | verkhnyaya inta
# Processing Record 267 | kaeo
# Processing Record 268 | klaksvik
# Processing Record 269 | leningradskiy
# Processing Record 270 | chapais
# Processing Record 271 | bhusawal
# Processing Record 272 | porto novo
# Processing Record 273 | slavutych
# Processing Record 274 | sabzevar
# Processing Record 275 | oktyabrskoye
# Processing Record 276 | barentsburg
# City not found. Skipping...
# Processing Record 277 | flores
# Processing Record 278 | ardistan
# City not found. Skipping...
# Processing Record 279 | coihaique
# Processing Record 280 | bayangol
# Processing Record 281 | ugoofaaru
# Processing Record 282 | jibuti
# Processing Record 283 | vestmannaeyjar
# Processing Record 284 | hasaki
# Processing Record 285 | malindi
# Processing Record 286 | te anau
# Processing Record 287 | oranjemund
# Processing Record 288 | kahului
# Processing Record 289 | bowen
# Processing Record 290 | college
# Processing Record 291 | bairiki
# Processing Record 292 | nouadhibou
# Processing Record 293 | saleaula
# City not found. Skipping...
# Processing Record 294 | cedar city
# Processing Record 295 | leshukonskoye
# Processing Record 296 | clarence town
# Processing Record 297 | husavik
# Processing Record 298 | southbridge
# Processing Record 299 | grenville
# Processing Record 300 | ponta do sol
# Processing Record 301 | marcona
# City not found. Skipping...
# Processing Record 302 | warqla
# City not found. Skipping...
# Processing Record 303 | buriti bravo
# Processing Record 304 | ilulissat
# Processing Record 305 | lincoln
# Processing Record 306 | lata
# Processing Record 307 | poole
# Processing Record 308 | solnechnyy
# Processing Record 309 | tsogni
# Processing Record 310 | susangerd
# Processing Record 311 | grand centre
# City not found. Skipping...
# Processing Record 312 | nara
# Processing Record 313 | kontagora
# Processing Record 314 | sainte-rose
# Processing Record 315 | nantucket
# Processing Record 316 | bam
# Processing Record 317 | ishigaki
# Processing Record 318 | kabare
# Processing Record 319 | gotsu
# Processing Record 320 | ekibastuz
# Processing Record 321 | nerchinskiy zavod
# Processing Record 322 | aksarka
# Processing Record 323 | san quintin
# Processing Record 324 | bur gabo
# City not found. Skipping...
# Processing Record 325 | nicoya
# Processing Record 326 | sorong
# Processing Record 327 | safford
# Processing Record 328 | ceglie messapica
# Processing Record 329 | sozimskiy
# Processing Record 330 | andros town
# Processing Record 331 | nanortalik
# Processing Record 332 | pacific grove
# Processing Record 333 | seoul
# Processing Record 334 | xochihuehuetlan
# Processing Record 335 | luwingu
# Processing Record 336 | eskasem
# City not found. Skipping...
# Processing Record 337 | ulaangom
# Processing Record 338 | mys shmidta
# City not found. Skipping...
# Processing Record 339 | marrakesh
# Processing Record 340 | nguiu
# City not found. Skipping...
# Processing Record 341 | cobija
# Processing Record 342 | puerto carreno
# Processing Record 343 | penzance
# Processing Record 344 | waipawa
# Processing Record 345 | olafsvik
# Processing Record 346 | tiksi
# Processing Record 347 | zhezkazgan
# Processing Record 348 | kankon
# Processing Record 349 | westerland
# Processing Record 350 | bay roberts
# Processing Record 351 | maniitsoq
# Processing Record 352 | vernon
# Processing Record 353 | sentyabrskiy
# City not found. Skipping...
# Processing Record 354 | mezen
# Processing Record 355 | fort nelson
# Processing Record 356 | fortuna
# Processing Record 357 | piranhas
# Processing Record 358 | gushikawa
# Processing Record 359 | sao joao da barra
# Processing Record 360 | shache
# Processing Record 361 | laramie
# Processing Record 362 | hefei
# Processing Record 363 | lucapa
# Processing Record 364 | mudyuga
# City not found. Skipping...
# Processing Record 365 | mount isa
# Processing Record 366 | lemesos
# City not found. Skipping...
# Processing Record 367 | komsomolskiy
# Processing Record 368 | gari
# Processing Record 369 | luderitz
# Processing Record 370 | carauari
# Processing Record 371 | biak
# Processing Record 372 | kibala
# Processing Record 373 | karkaralinsk
# City not found. Skipping...
# Processing Record 374 | clearwater
# Processing Record 375 | chicama
# Processing Record 376 | teya
# Processing Record 377 | benguela
# Processing Record 378 | gusinoye ozero
# Processing Record 379 | bindi
# Processing Record 380 | mecca
# Processing Record 381 | vaitupu
# City not found. Skipping...
# Processing Record 382 | akyab
# Processing Record 383 | yanji
# Processing Record 384 | salinas
# Processing Record 385 | deputatskiy
# Processing Record 386 | barberton
# Processing Record 387 | yangjiang
# Processing Record 388 | coquimbo
# Processing Record 389 | asosa
# Processing Record 390 | hofn
# Processing Record 391 | linqing
# Processing Record 392 | inhambane
# Processing Record 393 | lavrentiya
# Processing Record 394 | tezu
# Processing Record 395 | yebaishou
# Processing Record 396 | arrifes
# Processing Record 397 | goya
# Processing Record 398 | sar-e pul
# Processing Record 399 | makiyivka
# Processing Record 400 | zhigansk
# Processing Record 401 | maarianhamina
# Processing Record 402 | suntar
# Processing Record 403 | oistins
# Processing Record 404 | liverpool
# Processing Record 405 | gautier
# Processing Record 406 | belaya gora
# Processing Record 407 | batagay-alyta
# Processing Record 408 | victoria
# Processing Record 409 | dingle
# Processing Record 410 | tarsus
# Processing Record 411 | kita
# Processing Record 412 | schweinfurt
# Processing Record 413 | tual
# Processing Record 414 | dawson creek
# Processing Record 415 | tungor
# Processing Record 416 | samusu
# City not found. Skipping...
# Processing Record 417 | labuhan
# Processing Record 418 | broken hill
# Processing Record 419 | tura
# Processing Record 420 | portoferraio
# Processing Record 421 | matagami
# Processing Record 422 | adilcevaz
# Processing Record 423 | yanam
# Processing Record 424 | roura
# Processing Record 425 | coaldale
# Processing Record 426 | baykit
# Processing Record 427 | guarapari
# Processing Record 428 | sobolevo
# Processing Record 429 | itaituba
# Processing Record 430 | maghama
# City not found. Skipping...
# Processing Record 431 | dzhida
# Processing Record 432 | bahir dar
# Processing Record 433 | tabuk
# Processing Record 434 | valdivia
# Processing Record 435 | acworth
# Processing Record 436 | bimbo
# Processing Record 437 | lasa
# Processing Record 438 | barcelos
# Processing Record 439 | bugama
# Processing Record 440 | bereda
# Processing Record 441 | trofors
# Processing Record 442 | abnub
# Processing Record 443 | tabiauea
# City not found. Skipping...
# Processing Record 444 | burnie
# Processing Record 445 | abu jubayhah
# City not found. Skipping...
# Processing Record 446 | lahij
# Processing Record 447 | vargashi
# Processing Record 448 | tautira
# Processing Record 449 | coos bay
# Processing Record 450 | kutum
# Processing Record 451 | chany
# Processing Record 452 | rajapur
# Processing Record 453 | morondava
# Processing Record 454 | makurdi
# Processing Record 455 | santa cruz
# Processing Record 456 | hukuntsi
# Processing Record 457 | rudarpur
# Processing Record 458 | huntington
# Processing Record 459 | bargal
# City not found. Skipping...
# Processing Record 460 | vardo
# Processing Record 461 | gladstone
# Processing Record 462 | jalu
# Processing Record 463 | qasigiannguit
# Processing Record 464 | marystown
# Processing Record 465 | loandjili
# Processing Record 466 | swan hill
# Processing Record 467 | omboue
# Processing Record 468 | marsala
# Processing Record 469 | teguise
# Processing Record 470 | chaiyaphum
# Processing Record 471 | chuy
# Processing Record 472 | luocheng
# Processing Record 473 | vung tau
# Processing Record 474 | broome
# Processing Record 475 | huittinen
# Processing Record 476 | goderich
# Processing Record 477 | gariaband
# Processing Record 478 | mercedes
# Processing Record 479 | avera
# Processing Record 480 | menongue
# Processing Record 481 | havelock
# Processing Record 482 | payo
# Processing Record 483 | araguaina
# Processing Record 484 | zhanaozen
# Processing Record 485 | namatanai
# Processing Record 486 | clinton
# Processing Record 487 | yamada
# Processing Record 488 | ilo
# Processing Record 489 | chegutu
# Processing Record 490 | mitchell
# Processing Record 491 | alice springs
# Processing Record 492 | glubokoe
# City not found. Skipping...
# Processing Record 493 | grand gaube
# Processing Record 494 | laurel
# Processing Record 495 | jizan
# Processing Record 496 | inza
# Processing Record 497 | ostashkov
# Processing Record 498 | sao filipe
# Processing Record 499 | iberia
# Processing Record 500 | rocha
# Processing Record 501 | williams lake
# Processing Record 502 | den helder
# Processing Record 503 | hanmer springs
# Processing Record 504 | porto santo
# Processing Record 505 | dovers
# Processing Record 506 | saint-joseph
# Processing Record 507 | palabuhanratu
# City not found. Skipping...
# Processing Record 508 | kongwa
# Processing Record 509 | boa vista
# Processing Record 510 | semporna
# Processing Record 511 | tilichiki
# Processing Record 512 | banting
# Processing Record 513 | pilao arcado
# City not found. Skipping...
# Processing Record 514 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 515 | one hundred mile house
# City not found. Skipping...
# Processing Record 516 | meulaboh
# Processing Record 517 | panguna
# Processing Record 518 | garowe
# Processing Record 519 | dalnerechensk
# Processing Record 520 | tuktoyaktuk
# Processing Record 521 | sungaipenuh
# Processing Record 522 | calabozo
# Processing Record 523 | nihommatsu
# Processing Record 524 | kangaatsiaq
# Processing Record 525 | qui nhon
# Processing Record 526 | kambove
# Processing Record 527 | ende
# Processing Record 528 | samus
# Processing Record 529 | bathsheba
# Processing Record 530 | tsienyane
# City not found. Skipping...
# Processing Record 531 | cayenne
# Processing Record 532 | arlit
# Processing Record 533 | adrar
# Processing Record 534 | loei
# Processing Record 535 | igarka
# Processing Record 536 | panaba
# Processing Record 537 | alangayam
# Processing Record 538 | tsihombe
# City not found. Skipping...
# Processing Record 539 | solovetskiy
# City not found. Skipping...
# Processing Record 540 | abu dhabi
# Processing Record 541 | lolua
# City not found. Skipping...
# Processing Record 542 | filingue
# Processing Record 543 | eureka
# Processing Record 544 | bababe
# City not found. Skipping...
# Processing Record 545 | placido de castro
# Processing Record 546 | constitucion
# Processing Record 547 | hamilton
# Processing Record 548 | karangampel
# Processing Record 549 | tombouctou
# Processing Record 550 | kaoma
# Processing Record 551 | copacabana
# Processing Record 552 | ascoli piceno
# Processing Record 553 | sunrise manor
# Processing Record 554 | mananjary
# Processing Record 555 | sibolga
# Processing Record 556 | lubsko
# Processing Record 557 | taiyuan
# Processing Record 558 | vila
# Processing Record 559 | chumikan
# Processing Record 560 | sidney
# Processing Record 561 | illapel
# Processing Record 562 | mantua
# Processing Record 563 | launceston
# Processing Record 564 | nome
# Processing Record 565 | coahuayana
# Processing Record 566 | paracuru
# Processing Record 567 | kayerkan
# Processing Record 568 | balkhash
# Processing Record 569 | razdolnoye
# Processing Record 570 | arraial do cabo
# Processing Record 571 | choya
# Processing Record 572 | padang
# Processing Record 573 | pierre
# Processing Record 574 | roald
# Processing Record 575 | katsuura
# Processing Record 576 | phalodi
# Processing Record 577 | nioro
# Processing Record 578 | abu samrah
# Processing Record 579 | dillon
# Processing Record 580 | laguna
# Processing Record 581 | vostok
# Processing Record 582 | tiarei
# Processing Record 583 | ancud
# Processing Record 584 | kismayo
# Processing Record 585 | haapiti
# Processing Record 586 | bambanglipuro
# Processing Record 587 | havoysund
# Processing Record 588 | codrington
# Processing Record 589 | chimichagua
# Processing Record 590 | bima
# Processing Record 591 | karratha
# Processing Record 592 | conceicao do araguaia
# Processing Record 593 | faya
# Processing Record 594 | nuuk
# Processing Record 595 | pingliang
# Processing Record 596 | straumen
# Processing Record 597 | alofi
# Processing Record 598 | sumbawa
# City not found. Skipping...
# Processing Record 599 | labutta
# City not found. Skipping...
# Processing Record 600 | parainen
# Processing Record 601 | khingansk
# Processing Record 602 | bukachacha
# Processing Record 603 | ferrol
# Processing Record 604 | gobabis
# Processing Record 605 | salalah
# Processing Record 606 | dzhusaly
# City not found. Skipping...
# Processing Record 607 | boden
# Processing Record 608 | tessalit
# Processing Record 609 | xining
# Processing Record 610 | port hedland
# Processing Record 611 | vrangel
# Processing Record 612 | northam
# Processing Record 613 | mastic beach
# Processing Record 614 | carutapera
# Processing Record 615 | walvis bay
# Processing Record 616 | the valley
# Processing Record 617 | ambulu
# Processing Record 618 | bulgan
# Processing Record 619 | ati
# Processing Record 620 | putina
# Processing Record 621 | kerema
# Processing Record 622 | yumen
# Processing Record 623 | belonia
# Processing Record 624 | rzhev
# Processing Record 625 | kondinskoye
# Processing Record 626 | saint-georges
# Processing Record 627 | roebourne
# Processing Record 628 | pitimbu
# Processing Record 629 | visby
# Processing Record 630 | mujiayingzi
# Processing Record 631 | teknaf
# Processing Record 632 | rungata
# City not found. Skipping...
# Processing Record 633 | kuryk
# Processing Record 634 | shkotovo-26
# City not found. Skipping...
# Processing Record 635 | vestmanna
# Processing Record 636 | lang son
# Processing Record 637 | beloha
# Processing Record 638 | kenai
# Processing Record 639 | luancheng
# Processing Record 640 | sinjai
# Processing Record 641 | suao
# City not found. Skipping...
# Processing Record 642 | tapiramuta
# Processing Record 643 | la palma
# Processing Record 644 | dilla
# Processing Record 645 | eyl
# Processing Record 646 | fushun
# Processing Record 647 | kudahuvadhoo
# Processing Record 648 | angoche
# Processing Record 649 | lazaro cardenas
# Processing Record 650 | sao gabriel da cachoeira
# Processing Record 651 | chimbote
# Processing Record 652 | sangar
# Processing Record 653 | sovetskiy
# Processing Record 654 | do gonbadan
# Processing Record 655 | paucartambo
# City not found. Skipping...
# Processing Record 656 | rawah
# Processing Record 657 | kuusamo
# Processing Record 658 | hobyo
# Processing Record 659 | peleduy
# Processing Record 660 | quelimane
# Processing Record 661 | george
# Processing Record 662 | nowogard
# Processing Record 663 | port macquarie
# Processing Record 664 | rovaniemi
# Processing Record 665 | monte cristi
# City not found. Skipping...
# Processing Record 666 | plainview
# Processing Record 667 | tazovskiy
# Processing Record 668 | atambua
# Processing Record 669 | taybad
# Processing Record 670 | wichian buri
# Processing Record 671 | crotone
# Processing Record 672 | songea
# Processing Record 673 | xiongzhou
# Processing Record 674 | cockburn harbour
# City not found. Skipping...
# Processing Record 675 | kulmbach
# Processing Record 676 | rota
# Processing Record 677 | taltal
# Processing Record 678 | monrovia
# Processing Record 679 | tramandai
# Processing Record 680 | jasper
# Processing Record 681 | viedma
# Processing Record 682 | zhetybay
# City not found. Skipping...
# Processing Record 683 | bandarbeyla
# Processing Record 684 | gedo
# Processing Record 685 | ayan
# Processing Record 686 | mizan teferi
# Processing Record 687 | keetmanshoop
# Processing Record 688 | sabang
# Processing Record 689 | nemuro
# Processing Record 690 | ambilobe
# Processing Record 691 | maneadero
# Processing Record 692 | severnyy
# Processing Record 693 | znamenka
# Processing Record 694 | rabaul
# Processing Record 695 | tupik
# Processing Record 696 | abu kamal
# Processing Record 697 | yulara
# Processing Record 698 | bratsk
# Processing Record 699 | dolgoye
# Processing Record 700 | sur
# Processing Record 701 | miraflores
# Processing Record 702 | north bend
# Processing Record 703 | almeirim
# Processing Record 704 | kendari
# Processing Record 705 | sataua
# City not found. Skipping...
# Processing Record 706 | wollongong
# Processing Record 707 | port hardy
# Processing Record 708 | oksfjord
# Processing Record 709 | ankazobe
# Processing Record 710 | thohoyandou
# Processing Record 711 | tumut
# Processing Record 712 | khasan
# Processing Record 713 | amarpur
# Processing Record 714 | kabwe
# Processing Record 715 | nordfjordeid
# Processing Record 716 | hearst
# Processing Record 717 | ust-kulom
# Processing Record 718 | pucallpa
# Processing Record 719 | madang
# Processing Record 720 | tawkar
# City not found. Skipping...
# Processing Record 721 | paita
# Processing Record 722 | clemencia
# Processing Record 723 | westport
# Processing Record 724 | aflu
# City not found. Skipping...
# Processing Record 725 | kloulklubed
# Processing Record 726 | okakarara
# Processing Record 727 | port lincoln
# Processing Record 728 | dodola
# Processing Record 729 | zavodoukovsk
# Processing Record 730 | taungdwingyi
# Processing Record 731 | jaynagar-majilpur
# Processing Record 732 | abrau-dyurso
# Processing Record 733 | greenville
# Processing Record 734 | hongan
# City not found. Skipping...
# Processing Record 735 | scottsbluff
# Processing Record 736 | gasa
# Processing Record 737 | kachiry
# Processing Record 738 | jutai
# Processing Record 739 | murwara
# Processing Record 740 | heidelberg
# Processing Record 741 | melita
# Processing Record 742 | tigil
# Processing Record 743 | navalgund
# Processing Record 744 | bom jesus da lapa
# Processing Record 745 | waingapu
# Processing Record 746 | anito
# Processing Record 747 | dryden
# Processing Record 748 | eirunepe
# Processing Record 749 | novopavlovka
# Processing Record 750 | siocon
# Processing Record 751 | makakilo city
# Processing Record 752 | mae hong son
# Processing Record 753 | ilhabela
# Processing Record 754 | yurkivka
# Processing Record 755 | jerantut
# Processing Record 756 | gremyachinsk
# Processing Record 757 | saint-francois
# Processing Record 758 | oliveira
# Processing Record 759 | dekoa
# City not found. Skipping...
# Processing Record 760 | bridlington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Belozerskoye      RU  55.8214   65.5842     54.99        66           5
# 1     Mahebourg      MU -20.4081   57.7000     72.27        81          28
# 2        Rawson      AR -43.3002  -65.1023     45.37        56           0
# 3      Hermanus      ZA -34.4187   19.2345     60.91        44           7
# 4         Bluff      NZ -46.6000  168.3333     49.80        71          74
# 5        Albany      US  42.6001  -73.9662     79.45        67           6
# 6       Kavieng      PG  -2.5744  150.7967     82.90        73         100
# 7   Port Alfred      ZA -33.5906   26.8910     56.82        63           0
# 8       Rikitea      PF -23.1203 -134.9692     76.12        79           8
# 9        Torbay      CA  47.6666  -52.7314     54.28        97         100
#
#    Wind Speed Current Description
# 0        4.81           clear sky
# 1        3.36    scattered clouds
# 2       12.03           clear sky
# 3        8.59           clear sky
# 4        5.77       broken clouds
# 5        9.62           clear sky
# 6        3.65       moderate rain
# 7       12.64           clear sky
# 8       13.02           clear sky
# 9        1.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
